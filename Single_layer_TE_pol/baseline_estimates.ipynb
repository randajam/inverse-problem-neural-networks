# %% [markdown]
# # Baseline estimates
#
# - **Least Squares (LS)**
# - **Tikhonov regularization**
# - **Levenberg–Marquardt (LM) algorithm**

# %% [markdown]
# ## Least Squares

# %%
import numpy as np
from scipy.optimize import least_squares
